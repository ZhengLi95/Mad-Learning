# %% [markdown]
# # Pandas数据读入

# %%
import pandas as pd

# %%
train=pd.read_csv('/home/skylark/PythonProjects/SVM_Titanic/train.csv')

# %%
test=pd.read_csv('/home/skylark/PythonProjects/SVM_Titanic/test.csv')

# %% [markdown]
# ### 查看训练数据集信息

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # 导入需要的包，进行数据处理

# %%
# Importing packages
import numpy as np
import pandas as pd
import os
from pandas import DataFrame,Series
from sklearn import tree
import matplotlib
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.preprocessing import StandardScaler
import statsmodels.formula.api as smf
import statsmodels.api as sm
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
from sklearn import neighbors
from sklearn import linear_model
# %matplotlib inline
# Out:
# /home/skylark/anaconda2/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
surv = train['Survived'] == 1
die = train['Survived'] == 0
plt.figure(figsize=[12,10])
plt.subplot(321)
sns.barplot('Sex','Survived',data = train)
plt.subplot(322)
sns.barplot('Pclass','Survived',data = train)
plt.subplot(323)
sns.barplot('Age','Survived',data = train)
plt.subplot(324)
sns.distplot(train[surv]['Age'].dropna().values, bins=range(0, 81, 1), kde=False, color='blue')
sns.distplot(train[die]['Age'].dropna().values, bins=range(0, 81, 1), kde=False, color='red')
plt.subplot(325)
sns.barplot('SibSp','Survived',data = train)
plt.subplot(326)
sns.barplot('Parch','Survived',data = train)
# Out:
# /home/skylark/anaconda2/lib/python2.7/site-packages/seaborn/categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %% [markdown]
# ## 一副揭示'Pclass'，'Sex'与'Survived'关系的琴图
# 与本文无关

# %%
surv = train['Survived'] == 1
die = train['Survived'] == 0
plt.figure(figsize=[12,10])
sns.violinplot('Pclass','Survived',hue='Sex',data = train, split=True, inner="stick", palette="Set3")
# Out:
# /home/skylark/anaconda2/lib/python2.7/site-packages/seaborn/categorical.py:647: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data[hue_mask])
# /home/skylark/anaconda2/lib/python2.7/site-packages/seaborn/categorical.py:895: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data[hue_mask])
# /home/skylark/anaconda2/lib/python2.7/site-packages/seaborn/categorical.py:915: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)

# %% [markdown]
# # 数据处理
# ### 数据数值化('Sex', 'Embarked')

# %%
sex = np.zeros(len(train))
sex[train['Sex']== 'male'] = 1
sex[train['Sex']== 'female'] = 0
train['Sex'] = sex

train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  1.0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  0.0  38.0      1      0
# 2                             Heikkinen, Miss. Laina  0.0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  0.0  35.0      1      0
# 4                           Allen, Mr. William Henry  1.0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
train['Embarked'].fillna(train['Embarked'].mode()[0],inplace=True)
Embarked = np.zeros(len(train))
Embarked[train['Embarked']== 'C'] = 1
Embarked[train['Embarked']== 'Q'] = 2
Embarked[train['Embarked']== 'S'] = 3
train['Embarked'] = Embarked
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  1.0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  0.0  38.0      1      0
# 2                             Heikkinen, Miss. Laina  0.0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  0.0  35.0      1      0
# 4                           Allen, Mr. William Henry  1.0  35.0      0      0
#
#              Ticket     Fare Cabin  Embarked
# 0         A/5 21171   7.2500   NaN       3.0
# 1          PC 17599  71.2833   C85       1.0
# 2  STON/O2. 3101282   7.9250   NaN       3.0
# 3            113803  53.1000  C123       3.0
# 4            373450   8.0500   NaN       3.0

# %% [markdown]
# ### 删除数据集中的无用信息('PassengerId','Name', 'Ticket')
# ### 删除缺失严重的信息('Cabin')

# %%
print(type(train))
dropping = ['PassengerId','Name', 'Ticket','Cabin']
train.drop(dropping,axis=1, inplace=True)
test.drop(dropping,axis=1, inplace=True)
train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3  1.0  22.0      1      0   7.2500       3.0
# 1         1       1  0.0  38.0      1      0  71.2833       1.0
# 2         1       3  0.0  26.0      0      0   7.9250       3.0
# 3         1       1  0.0  35.0      1      0  53.1000       3.0
# 4         0       3  1.0  35.0      0      0   8.0500       3.0

# %% [markdown]
# ### 利用平均值填补'Age'数据缺失

# %%
train['Age'].fillna(train['Age'].mean(),inplace=True)
age = np.zeros(len(train))
age[train['Age']<20] = 1
age[(train['Age']>=20)&(train['Age']<60)] = 2
age[(train['Age']>=60)] = 3
train['Age'] = age
train.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare  Embarked
# 0         0       3  1.0  2.0      1      0   7.2500       3.0
# 1         1       1  0.0  2.0      1      0  71.2833       1.0
# 2         1       3  0.0  2.0      0      0   7.9250       3.0
# 3         1       1  0.0  2.0      1      0  53.1000       3.0
# 4         0       3  1.0  2.0      0      0   8.0500       3.0

# %% [markdown]
# # 绘制特征相关性的热力图

# %%
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(12, 10))
plt.title('Pearson Correlation of Movie Features')
# Draw the heatmap using seaborn
sns.heatmap(abs(train.astype(float).corr()),linewidths=0.25,vmax=1.0, square=True, cmap="YlGnBu", linecolor='black', annot=True)

# %% [markdown]
# ### 由相关性的热力图可知，Sex、Pclass、Fare对能否存活影响最大

# %% [markdown]
# # SVM模型

# %%
from sklearn import svm

# %%
train_y=train['Survived']
train_x=train.drop('Survived',axis=1)
print(train.head())
print(train_x.head())
print(train_y.head())
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare  Embarked
# 0         0       3  1.0  2.0      1      0   7.2500       3.0
# 1         1       1  0.0  2.0      1      0  71.2833       1.0
# 2         1       3  0.0  2.0      0      0   7.9250       3.0
# 3         1       1  0.0  2.0      1      0  53.1000       3.0
# 4         0       3  1.0  2.0      0      0   8.0500       3.0
#    Pclass  Sex  Age  SibSp  Parch     Fare  Embarked
# 0       3  1.0  2.0      1      0   7.2500       3.0
# 1       1  0.0  2.0      1      0  71.2833       1.0
# 2       3  0.0  2.0      0      0   7.9250       3.0
# 3       1  0.0  2.0      1      0  53.1000       3.0
# 4       3  1.0  2.0      0      0   8.0500       3.0
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
model=svm.SVC(kernel='linear').fit(train_x, train_y)

# %% [markdown]
# # 以相同方式处理测试数据

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 7 columns):
# Pclass      418 non-null int64
# Sex         418 non-null object
# Age         332 non-null float64
# SibSp       418 non-null int64
# Parch       418 non-null int64
# Fare        417 non-null float64
# Embarked    418 non-null object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 22.9+ KB

# %%
pd.DataFrame(test)
# Out:
#      Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0         3    male  34.5      0      0    7.8292        Q
# 1         3  female  47.0      1      0    7.0000        S
# 2         2    male  62.0      0      0    9.6875        Q
# 3         3    male  27.0      0      0    8.6625        S
# 4         3  female  22.0      1      1   12.2875        S
# 5         3    male  14.0      0      0    9.2250        S
# 6         3  female  30.0      0      0    7.6292        Q
# 7         2    male  26.0      1      1   29.0000        S
# 8         3  female  18.0      0      0    7.2292        C
# 9         3    male  21.0      2      0   24.1500        S
# 10        3    male   NaN      0      0    7.8958        S
# 11        1    male  46.0      0      0   26.0000        S
# 12        1  female  23.0      1      0   82.2667        S
# 13        2    male  63.0      1      0   26.0000        S
# 14        1  female  47.0      1      0   61.1750        S
# 15        2  female  24.0      1      0   27.7208        C
# 16        2    male  35.0      0      0   12.3500        Q
# 17        3    male  21.0      0      0    7.2250        C
# 18        3  female  27.0      1      0    7.9250        S
# 19        3  female  45.0      0      0    7.2250        C
# 20        1    male  55.0      1      0   59.4000        C
# 21        3    male   9.0      0      1    3.1708        S
# 22        1  female   NaN      0      0   31.6833        S
# 23        1    male  21.0      0      1   61.3792        C
# 24        1  female  48.0      1      3  262.3750        C
# 25        3    male  50.0      1      0   14.5000        S
# 26        1  female  22.0      0      1   61.9792        C
# 27        3    male  22.5      0      0    7.2250        C
# 28        1    male  41.0      0      0   30.5000        S
# 29        3    male   NaN      2      0   21.6792        C
# ..      ...     ...   ...    ...    ...       ...      ...
# 388       3    male  21.0      0      0    7.7500        Q
# 389       3    male   6.0      3      1   21.0750        S
# 390       1    male  23.0      0      0   93.5000        S
# 391       1  female  51.0      0      1   39.4000        S
# 392       3    male  13.0      0      2   20.2500        S
# 393       2    male  47.0      0      0   10.5000        S
# 394       3    male  29.0      3      1   22.0250        S
# 395       1  female  18.0      1      0   60.0000        S
# 396       3    male  24.0      0      0    7.2500        Q
# 397       1  female  48.0      1      1   79.2000        C
# 398       3    male  22.0      0      0    7.7750        S
# 399       3    male  31.0      0      0    7.7333        Q
# 400       1  female  30.0      0      0  164.8667        S
# 401       2    male  38.0      1      0   21.0000        S
# 402       1  female  22.0      0      1   59.4000        C
# 403       1    male  17.0      0      0   47.1000        S
# 404       1    male  43.0      1      0   27.7208        C
# 405       2    male  20.0      0      0   13.8625        C
# 406       2    male  23.0      1      0   10.5000        S
# 407       1    male  50.0      1      1  211.5000        C
# 408       3  female   NaN      0      0    7.7208        Q
# 409       3  female   3.0      1      1   13.7750        S
# 410       3  female   NaN      0      0    7.7500        Q
# 411       1  female  37.0      1      0   90.0000        Q
# 412       3  female  28.0      0      0    7.7750        S
# 413       3    male   NaN      0      0    8.0500        S
# 414       1  female  39.0      0      0  108.9000        C
# 415       3    male  38.5      0      0    7.2500        S
# 416       3    male   NaN      0      0    8.0500        S
# 417       3    male   NaN      1      1   22.3583        C
#
# [418 rows x 7 columns]

# %%
sex_test = np.zeros(len(test))
sex_test[test['Sex']== 'male'] = 1
sex_test[test['Sex']== 'female'] = 0
test['Sex'] = sex_test

# %%
test['Embarked'].fillna(test['Embarked'].mode()[0],inplace=True)
Embarked = np.zeros(len(test))
Embarked[test['Embarked']== 'C'] = 1
Embarked[test['Embarked']== 'Q'] = 2
Embarked[test['Embarked']== 'S'] = 3
test['Embarked'] = Embarked

# %%
age = np.zeros(len(test))
test['Age'].fillna(test['Age'].mean(),inplace=True)
age[test['Age']<20.0] = 1
age[(test['Age']>=20.0)&(test['Age']<60.0)] = 2
age[(test['Age']>=60.0)] = 3
test['Age'] = age
test['Fare'].fillna(test['Fare'].mean(),inplace=True)
test.head()
# Out:
#    Pclass  Sex  Age  SibSp  Parch     Fare  Embarked
# 0       3  1.0  2.0      0      0   7.8292       2.0
# 1       3  0.0  2.0      1      0   7.0000       3.0
# 2       2  1.0  3.0      0      0   9.6875       2.0
# 3       3  1.0  2.0      0      0   8.6625       3.0
# 4       3  0.0  2.0      1      1  12.2875       3.0

# %%
np.sum(test.isnull())
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# # 预测

# %%
predictions = model.predict(test)

# %%
test_rare=pd.read_csv('/home/skylark/PythonProjects/SVM_Titanic/test.csv')
submission = pd.DataFrame({ 'PassengerId': test_rare['PassengerId'],
                            'Survived': predictions })
submission.to_csv("result.csv", index=False)

# %% [markdown]
# ![2018-11-23%2016-00-00%20%E7%9A%84%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE.png](attachment:2018-11-23%2016-00-00%20%E7%9A%84%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE.png)

# %% [markdown]
# ![2018-11-23%2015-59-05%20%E7%9A%84%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE.png](attachment:2018-11-23%2015-59-05%20%E7%9A%84%E5%B1%8F%E5%B9%95%E6%88%AA%E5%9B%BE.png)

# %% [markdown]
# ## 由此可见，SVM对于这道题来说应该不是个好办法
